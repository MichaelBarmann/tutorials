# %%
using Pkg

# %%
env_path = "C:/Users/mbarm/.julia/environments/Makie_and_Plots_julia_v1.10.0/Project.toml"
Pkg.activate(env_path)
println("Current environment: ", Pkg.project().path)
# Out:
#   Activating project at `C:\Users\mbarm\.julia\environments\Makie_and_Plots_julia_v1.10.0`
# Current environment: C:\Users\mbarm\.julia\environments\Makie_and_Plots_julia_v1.10.0\Project.toml

# %%
Pkg.status()
# Out:
# Status `C:\Users\mbarm\.julia\environments\Makie_and_Plots_julia_v1.10.0\Project.toml`
#   [13f3f980] CairoMakie v0.15.4
# ⌃ [c87230d0] FFMPEG v0.2.4
# ⌃ [91a5bcdd] Plots v1.40.1
# Info Packages marked with ⌃ have new versions available and may be upgradable.

# %%
Pkg.rm("Plots")
Pkg.add("Plots")
# Out:
#     Updating `C:\Users\mbarm\.julia\environments\Makie_and_Plots_julia_v1.10.0\Project.toml`
#   [91a5bcdd] - Plots v1.40.1
#     Updating `C:\Users\mbarm\.julia\environments\Makie_and_Plots_julia_v1.10.0\Manifest.toml`
#   [d1d4a3ce] - BitFlags v0.1.9
#   [944b1d66] - CodecZlib v0.7.8
#   [f0e56b4a] - ConcurrentUtilities v2.5.0
#   [8bb1440f] - DelimitedFiles v1.9.1
#   [460bff9d] - ExceptionUnwrapping v0.1.11
#   [28b8d3ca] - GR v0.73.17
#   [cd3eb016] - HTTP v1.10.17
#   [1019f520] - JLFzf v0.1.11
#   [23fbe1c1] - Latexify v0.16.8
#   [e6f89c97] - LoggingExtras v1.1.0
#   [739be429] - MbedTLS v1.1.9
#   [442fdcdd] - Measures v0.3.2
#   [4d8831e6] - OpenSSL v1.5.0
#   [ccf2f8ad] - PlotThemes v3.3.0
#   [91a5bcdd] - Plots v1.40.1
#   [3cdcf5f2] - RecipesBase v1.3.4
#   [01d81517] - RecipesPipeline v0.6.12
#   [777ac1f9] - SimpleBufferStream v1.2.0
#   [5c2747f8] - URIs v1.6.1
#   [45397f5d] - UnitfulLatexify v1.7.0
#   [41fe7b60] - Unzip v0.2.0
#   [ee1fde0b] - Dbus_jll v1.16.2+0
# ...

# %%
Pkg.add("CairoMakie")

# %%
using CairoMakie, Plots
# Out:
# Precompiling Plots
#   ✗ Qt6ShaderTools_jll
#   ✗ GR_jll
#   ✗ BinaryProvider
#   ✗ Qt6Declarative_jll
#   ✗ FFMPEG
#   ✗ GR
#         Info Given Plots was explicitly requested, output will be shown live
# Deps path: C:\Users\mbarm\.julia\packages\FFMPEG\guN1x\src\..\deps\deps.jl
# ERROR: LoadError: FFMPEG not installed properly, run `] build FFMPEG`, restart Julia and try again
# Stacktrace:
#  [1] error(s::String)
#    @ Base .\error.jl:35
#  [2] top-level scope
#    @ C:\Users\mbarm\.julia\packages\FFMPEG\guN1x\src\FFMPEG.jl:23
#  [3] include
#    @ Base .\Base.jl:495 [inlined]
#  [4] include_package_for_output(pkg::Base.PkgId, input::String, depot_path::Vector{String}, dl_load_path::Vector{String}, load_path::Vector{String}, concrete_deps::Vector{Pair{Base.PkgId, UInt128}}, source::String)
#    @ Base .\loading.jl:2216
#  [5] top-level scope
#    @ stdin:3
# in expression starting at C:\Users\mbarm\.julia\packages\FFMPEG\guN1x\src\FFMPEG.jl:1
# in expression starting at stdin:3
# ...

# %%
Pkg.add("FFMPEG")
# Out:
#    Resolving package versions...
#   No Changes to `C:\Users\mbarm\.julia\environments\Makie_and_Plots_julia_v1.10.0\Project.toml`
#   No Changes to `C:\Users\mbarm\.julia\environments\Makie_and_Plots_julia_v1.10.0\Manifest.toml`

# %%
Pkg.build("FFMPEG")
# Out:
#     Building FFMPEG → `C:\Users\mbarm\.julia\scratchspaces\44cfe95a-1eb2-52ea-b672-e2afdf69b78f\9143266ba77d3313a4cf61d8333a1970e8c5d8b6\build.log`
# Error building `FFMPEG`:
# ERROR: LoadError: Unable to open libLLVM!
# Stacktrace:
#   [1] error(s::String)
#     @ Base .\error.jl:35
#   [2] (::BinaryProvider.var"#open_libllvm#124")()
#     @ BinaryProvider C:\Users\mbarm\.julia\packages\BinaryProvider\U2dKK\src\PlatformNames.jl:652
#   [3] detect_cxx11_string_abi()
#     @ BinaryProvider C:\Users\mbarm\.julia\packages\BinaryProvider\U2dKK\src\PlatformNames.jl:655
#   [4] detect_compiler_abi()
#     @ BinaryProvider C:\Users\mbarm\.julia\packages\BinaryProvider\U2dKK\src\PlatformNames.jl:668
#   [5] top-level scope
#     @ C:\Users\mbarm\.julia\packages\BinaryProvider\U2dKK\src\PlatformNames.jl:685
#   [6] include(mod::Module, _path::String)
#     @ Base .\Base.jl:495
#   [7] include(x::String)
# ...

# %%
using Pkg
Pkg.rm("FFMPEG")
Pkg.gc()  # Optional, cleans up unused packages
Pkg.add("FFMPEG")
Pkg.build("FFMPEG")
# Out:
#     Updating `C:\Users\mbarm\.julia\environments\Makie_and_Plots_julia_v1.10.0\Project.toml`
#   [c87230d0] - FFMPEG v0.2.4
#   No Changes to `C:\Users\mbarm\.julia\environments\Makie_and_Plots_julia_v1.10.0\Manifest.toml`
#       Active manifest files: 8 found
#       Active artifact files: 181 found
#       Active scratchspaces: 12 found
#      Deleted no artifacts, repos, packages or scratchspaces
#    Resolving package versions...
#     Updating `C:\Users\mbarm\.julia\environments\Makie_and_Plots_julia_v1.10.0\Project.toml`
# ⌃ [c87230d0] + FFMPEG v0.2.4
#   No Changes to `C:\Users\mbarm\.julia\environments\Makie_and_Plots_julia_v1.10.0\Manifest.toml`
#     Building FFMPEG → `C:\Users\mbarm\.julia\scratchspaces\44cfe95a-1eb2-52ea-b672-e2afdf69b78f\9143266ba77d3313a4cf61d8333a1970e8c5d8b6\build.log`
